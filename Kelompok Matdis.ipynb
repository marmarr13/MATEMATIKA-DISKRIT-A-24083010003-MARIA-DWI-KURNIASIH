# %% [markdown]
# <a href="https://colab.research.google.com/github/marmarr13/MATEMATIKA-DISKRIT-A-24083010003-MARIA-DWI-KURNIASIH/blob/main/Kelompok%20Matdis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TUGAS MATEMATIKA DISKRIT**
#
# **MARIA DWI KURNIASIH 24083010003**
#
# **HIZKIA SAMHAN REZAYOSHI 24083010019**
#
# **NAJWA SOFIA 24083010115**
#
# Pembagian tugas
#
# Maria : Menambah klaster, Memperbaiki visual
#
# Hizkia : Menambahkan klaster, Memperbaiki eror
#
# Sofia : Menambahkan klaster, Menambahkan sorce code yang diperlukan

# %%
import networkx as nx
import matplotlib.pyplot as plt

# --- Fungsi untuk menambahkan klaster dengan warna berbeda ---
def add_cluster_edges(graph, cluster, color):
    """Tambahkan edges antar anggota cluster dengan warna tertentu"""
    for i in range(len(cluster)):
        for j in range(i+1, len(cluster)):
            graph.add_edge(cluster[i], cluster[j], color=color)

# --- Buat graph dan nodes ---
G = nx.Graph()

mahasiswa = [
"Madina", "Maria", "Adinda", "Aquina", "Alimun", "Hizkia", "Raveena",
"Ophyng", "Aisyah", "Febriani", "Amelia", "Via", "Fanny", "Naia",
"Alfani", "Diah", "Kenzy", "Angel", "Maulida", "Izzati", "Auliya",
"Carissa", "Diva", "Erik", "Maya", "Dany", "Gendis", "Wildan", "Esthi",
"Naufal", "Laudya", "Adrian", "Selvy", "Hafiyyan", "Indra", "Yuniar",
"Kiky", "Sofia", "Varid", "Gaitsa"]
G.add_nodes_from(mahasiswa)

# --- Klaster pertemanan ---
# Misal beberapa klaster
akamsi = ["Via", "Esthi", "Indra", "Madina", "Maulida", "Kiky", "Diva"]
jabodetabek = ["Sofia", "Maria", "Fanny", "Gaitsa", "Aisyah", "Hizkia"]
platP = ["Angel", "Selvy", "Amelia"]
platS = ["Naia", "Izzati", "Varid", "Kiky"]
platM = ["Dany", "Alimun", "Kenzy", "Erik"]
platN = ["Alfani", "Diah", "Naufal"]
platAx = ["Adrian", "Selvy", "Fanny", "Gaitsa"]
sekos = ["Aisyah", "Naia", "Maria", "Angel", "Laudya", "Adrian", "Ophyng"]
himasada = ["Dany", "Esthi", "Naia", "Via", "Madina", "Alfani", "Maulida", "Febriani"]
BEMfakultas = ["Hafiyyan", "Varid", "Carissa", "Raveena", "Wildan"]
warkopbening = ["Wildan", "Dany", "Izzati", "Erik", "Hafiyyan", "Diah", "Kenzy"]
skincaredanmakeup = ["Hizkia", "Kiky", "Sofia", "Maria", "Yuniar"]
makanbareng = ["Ophyng", "Varid", "Gaitsa", "Carissa", "Diva", "Aquina", "Sofia"]
nontonfilm = ["Febriani", "laudya", "Naufal", "Adinda", "Auliya", "Gendis", "Maya", "Adrian"]
UKM = ["Maria", "Ophyng"]
kerja = ["Varid", "Wildan"]
Panitia = ["Ophyng", "Maria", "Hizkia", "Sofia", "Via", "Esthi", "Carissa", "Madina", "Varid", "Maulida", "Naufal",
           "Selvy", "Dany", "Gaitsa", "Fanny", "Izzati", "Naia"]

# Warna klaster
clusters = [
    (akamsi, "red"),
    (jabodetabek, "blue"),
    (platP, "green"),
    (platS, "purple"),
    (platM, "orange"),
    (platN, "brown"),
    (platAx, "pink"),
    (sekos, "cyan"),
    (himasada, "magenta"),
    (BEMfakultas, "yellow"),
    (warkopbening, "grey"),
    (skincaredanmakeup, "black"),
    (makanbareng, "lightgreen"),
    (nontonfilm, "darkblue"),
    (UKM, "maroon"),
    (kerja, "teal"),
    (Panitia, "lightgrey")
]

# Tambahkan edges sesuai klaster
for cluster, color in clusters:
    add_cluster_edges(G, cluster, color)

# --- Analisis ---
# 1) Orang dengan konektivitas paling banyak (degree)
degree_dict = dict(G.degree())
top3 = sorted(degree_dict.items(), key=lambda x: x[1], reverse=True)[:3]
print("Top 3 orang dengan konektivitas terbanyak:", top3)

# --- Pasangan terjauh koneksinya (diameter) ---
lengths = dict(nx.all_pairs_shortest_path_length(G))
max_distance = 0
pairs = set()  # pakai set supaya unik

for u in lengths:
    for v, dist in lengths[u].items():
        if u < v:  # hanya simpan u < v agar tidak duplikat
            if dist > max_distance:
                max_distance = dist
                pairs = {(u, v)}
            elif dist == max_distance:
                pairs.add((u, v))

pairs = list(pairs)
print("Pasangan terjauh koneksinya (jarak {}):".format(max_distance))
print(pairs)

# 3a) Bridge person (betweenness centrality)
betweenness = nx.betweenness_centrality(G)
top_bridges = sorted(betweenness.items(), key=lambda x: x[1], reverse=True)[:5]
print("Bridge person (top 5 betweenness):", top_bridges)

# 3b) Bridge person dengan koneksi paling sedikit (degree rendah tapi high betweenness)
low_degree_bridges = sorted(top_bridges, key=lambda x: degree_dict[x[0]])
print("Bridge person dengan koneksi sedikit:", low_degree_bridges)
# Out:
# Top 3 orang dengan konektivitas terbanyak: [('Naufal', 25), ('Dany', 24), ('Naia', 23)]
# Pasangan terjauh koneksinya (jarak 3):
# [('Gendis', 'Yuniar'), ('Adinda', 'Alimun'), ('Aisyah', 'Wildan'), ('Wildan', 'laudya'), ('Hafiyyan', 'Yuniar'), ('Kenzy', 'laudya'), ('Aquina', 'Diah'), ('Raveena', 'Yuniar'), ('Diva', 'Kenzy'), ('Kenzy', 'Laudya'), ('Adinda', 'Kenzy'), ('Auliya', 'Indra'), ('Amelia', 'Wildan'), ('Diva', 'Maya'), ('Auliya', 'Erik'), ('Gendis', 'Kenzy'), ('Amelia', 'Diva'), ('Angel', 'Kenzy'), ('Diah', 'Laudya'), ('Erik', 'laudya'), ('Alimun', 'laudya'), ('Diah', 'Indra'), ('Aisyah', 'Hafiyyan'), ('Hafiyyan', 'Maya'), ('Diva', 'Erik'), ('Erik', 'Laudya'), ('Adinda', 'Erik'), ('Alimun', 'Laudya'), ('Maya', 'Yuniar'), ('Diva', 'Gendis'), ('Alimun', 'Raveena'), ('Indra', 'Kenzy'), ('Erik', 'Indra'), ('Alimun', 'Indra'), ('Aisyah', 'Diah'), ('Adinda', 'Yuniar'), ('Alimun', 'Kiky'), ('Adrian', 'Wildan'), ('Alimun', 'Amelia'), ('Amelia', 'Aquina'), ('Amelia', 'Diah'), ('Auliya', 'Raveena'), ('Maya', 'Raveena'), ('Adrian', 'Erik'), ('Diva', 'laudya'), ('Alfani', 'Raveena'), ('Kiky', 'Maya'), ('Adinda', 'Raveena'), ('Auliya', 'Wildan'), ('Auliya', 'Kiky'), ('Erik', 'Gendis'), ('Hafiyyan', 'laudya'), ('Adinda', 'Indra'), ('Gendis', 'Raveena'), ('Amelia', 'Kenzy'), ('Angel', 'Raveena'), ('Adrian', 'Hafiyyan'), ('Aquina', 'Kenzy'), ('Raveena', 'laudya'), ('Hafiyyan', 'Laudya'), ('Gendis', 'Indra'), ('Angel', 'Indra'), ('Adinda', 'Kiky'), ('Alfani', 'Amelia'), ('Aquina', 'Maya'), ('Adinda', 'Amelia'), ('Hafiyyan', 'Indra'), ('Angel', 'Erik'), ('Diah', 'Diva'), ('Indra', 'Maya'), ('Gendis', 'Wildan'), ('Gendis', 'Kiky'), ('Indra', 'Raveena'), ('Amelia', 'Auliya'), ('Aquina', 'Auliya'), ('Amelia', 'Erik'), ('Auliya', 'Hafiyyan'), ('Yuniar', 'laudya'), ('Aquina', 'Erik'), ('Amelia', 'Gendis'), ('Aisyah', 'Alimun'), ('Alimun', 'Diva'), ('Aquina', 'Gendis'), ('Amelia', 'Yuniar'), ('Aisyah', 'Kenzy'), ('Adinda', 'Hafiyyan'), ('Adrian', 'Kenzy'), ('Kiky', 'laudya'), ('Wildan', 'Yuniar'), ('Laudya', 'Raveena'), ('Gendis', 'Hafiyyan'), ('Kenzy', 'Yuniar'), ('Auliya', 'Diva'), ('Maya', 'Wildan'), ('Aquina', 'Febriani'), ('Febriani', 'Yuniar'), ('Aisyah', 'Indra'), ('Diah', 'Yuniar'), ('Laudya', 'Wildan'), ('Aquina', 'laudya'), ('Amelia', 'Maya'), ('Alimun', 'Angel'), ('Adinda', 'Wildan'), ('Aisyah', 'Erik'), ('Alimun', 'Aquina'), ('Amelia', 'Raveena'), ('Indra', 'laudya'), ('Adinda', 'Diva'), ('Erik', 'Yuniar'), ('Indra', 'Laudya'), ('Angel', 'Wildan'), ('Alimun', 'Yuniar'), ('Amelia', 'Indra'), ('Kenzy', 'Maya'), ('Adrian', 'Alimun'), ('Amelia', 'Kiky'), ('Febriani', 'Raveena'), ('Indra', 'Wildan'), ('Auliya', 'Yuniar'), ('Erik', 'Maya'), ('Alimun', 'Maya'), ('Angel', 'Hafiyyan'), ('Alfani', 'Aquina'), ('Aisyah', 'Raveena'), ('Adinda', 'Aquina'), ('Amelia', 'Febriani'), ('Adrian', 'Raveena'), ('Alfani', 'Yuniar'), ('Adrian', 'Indra'), ('Alimun', 'Auliya'), ('Amelia', 'Hafiyyan'), ('Amelia', 'laudya'), ('Auliya', 'Kenzy'), ('Angel', 'Diah'), ('Alimun', 'Gendis')]
# Bridge person (top 5 betweenness): [('Naufal', 0.14629269046581236), ('Dany', 0.11558540163831892), ('Izzati', 0.0617935068986691), ('Adrian', 0.052140450361345306), ('Varid', 0.049548598840567976)]
# Bridge person dengan koneksi sedikit: [('Adrian', 0.052140450361345306), ('Izzati', 0.0617935068986691), ('Varid', 0.049548598840567976), ('Dany', 0.11558540163831892), ('Naufal', 0.14629269046581236)]

# %%
import networkx as nx
import plotly.graph_objects as go

def draw_graph_plotly(graph, k_value=2.0):
    # posisi node pakai spring_layout
    pos = nx.spring_layout(graph, k=k_value, iterations=200)

    # --- Edge trace ---
    edge_x = []
    edge_y = []
    for u, v in graph.edges():
        x0, y0 = pos[u]
        x1, y1 = pos[v]
        edge_x.extend([x0, x1, None])
        edge_y.extend([y0, y1, None])

    edge_trace = go.Scatter(
        x=edge_x, y=edge_y,
        line=dict(width=2, color='#888'),
        hoverinfo='none',
        mode='lines'
    )

    # --- Node trace ---
    node_x = []
    node_y = []
    node_text = []
    for node in graph.nodes():
        x, y = pos[node]
        node_x.append(x)
        node_y.append(y)
        node_text.append(str(node))  # Bisa diganti info lain

    node_trace = go.Scatter(
        x=node_x, y=node_y,
        mode='markers+text',
        text=node_text,
        textposition='top center',
        hoverinfo='text',
        marker=dict(color='skyblue', size=20, line_width=2)
    )

    # --- Figure ---
    fig = go.Figure(data=[edge_trace, node_trace],
                    layout=go.Layout(
                        showlegend=False,
                        hovermode='closest',
                        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)
                    ))
    fig.show()

# --- Contoh pemanggilan ---
draw_graph_plotly(G, k_value=1.2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d6e80827-1ad0-48c8-8480-5a10500e75b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d